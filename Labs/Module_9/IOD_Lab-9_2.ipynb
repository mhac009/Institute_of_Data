# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 9.2: Web Scraping
# INSTRUCTIONS:
# - Read the guides and hints then create the necessary analysis and code to find an answer and conclusion for the task below.

# %% [markdown]
# # Web Scraping in Python (using BeautifulSoup)
#
# ## Scraping Rules
# 1. **Always** check a website’s **Terms and Conditions** before you scrape it. Be careful to read the statements about legal use of data. Usually, the retrieved data should not be used for commercial purposes.
# 2. **Do not** request data from the website too aggressively with a program (also known as spamming), as this may break the website. Make sure the program behaves in a reasonable manner (i.e. acts like a human). One request for one webpage per second is good practice.
# 3. The layout of a website may change from time to time, so make sure to revisit the site and rewrite the code as needed

# %% [markdown]
# ## Find a Page
# Visit the [Fandom](http://fandom.wikia.com) website, find a wikia of your interest and pick a page to work with.

# %% [markdown]
# Open a web page with the browser and inspect it.
#
# Hover the cursor on the text and follow the shaded box surrounding the main text.
#
# From the result, check the main text inside a few levels of HTML tags.

# %%
## Import Libraries
import regex as re

from urllib.parse import unquote
import urllib3
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Define the content to retrieve (webpage's URL)

# %%
quote_page = 'https://elderscrolls.fandom.com/wiki/The_Elder_Scrolls_Wiki'

# %% [markdown]
# ### Retrieve the page
# - Require Internet connection

# %%
http = urllib3.PoolManager()
r = http.request('GET', quote_page)
if r.status == 200:
    page = r.data
    print('Type of the variable \'page\':', page.__class__.__name__)
    print('Page Retrieved. Request Status: %d, Page Size: %d' % (r.status, len(page)))
else:
    print('Some problem occurred. Request Status: %s' % r.status)
# Out:
# Type of the variable 'page': bytes
# Page Retrieved. Request Status: 200, Page Size: 249188

# %% [markdown]
# ### Convert the stream of bytes into a BeautifulSoup representation

# %%
soup = BeautifulSoup(page, 'html.parser')
print('Type of the variable \'soup\':', soup.__class__.__name__)
# Out:
# Type of the variable 'soup': BeautifulSoup

# %% [markdown]
# ### Check the content
# - The HTML source
# - Includes all tags and scripts
# - Can be long!

# %%
print(soup.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Elder Scrolls | Fandom
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
#    (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"The_Elder_Scrolls_Wiki","wgTitle":"The Elder Scrolls Wiki","wgCurRevisionId":3121405,"wgRevisionId":3121405,"wgArticleId":123863,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["The Elder Scrolls Wiki"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","

# %% [markdown]
# ### Check the HTML's Title

# %%
print('Title tag :%s:' % soup.title)
print('Title text:%s:' % soup.title.string)
# Out:
# Title tag :<title>Elder Scrolls | Fandom</title>:
# Title text:Elder Scrolls | Fandom:

# %% [markdown]
# ### Find the main content
# - Check if it is possible to use only the relevant data

# %% [markdown]
# ### Get some of the text
# - Plain text without HTML tags

# %%
# show the first 500 characters after removing redundant newlines
print(re.sub(r'\n\n+', '\n', soup.text)[:500])
# Out:
# Elder Scrolls | Fandom
#
# 	Games
# 	Movies
# 	TV
# 	Video
# Wikis
#
# 	Explore Wikis
# 	Community Central
# 	Start a Wiki
#
# 				Search
# 							This wiki
# 								This wiki
# 								All wikis
# 				 |
#
#
#
#
#
# 					Sign In
# Don't have an account?
# 					Register
# 	Start a Wiki
# Elder Scrolls
# 67,822
# Pages
#  Add new page
# Elder Scrolls Online
#
# Quests
#
# Main Quest
# Aldmeri Dominion
# Daggerfall Covenant
# Ebonheart Pact
# Side Quests
# Alliances
#
# Aldmeri Dominion
# Daggerfall Covenant
# Ebonheart Pac

# %% [markdown]
# ### Find the links in the text

# %%
# identify the type of tag to retrieve
tag = 'a'
# create a list with the links from the `<a>` tag
tag_list = [t.get('href') for t in soup.find_all(tag)]
tag_list
# Out:
# ['https://www.fandom.com/',
#  'https://www.fandom.com/topics/games',
#  'https://www.fandom.com/topics/movies',
#  'https://www.fandom.com/topics/tv',
#  'https://www.fandom.com/video',
#  'https://www.fandom.com/explore',
#  '//community.fandom.com/wiki/Community_Central',
#  '//community.fandom.com/wiki/Special:CreateNewWiki',
#  None,
#  None,
#  'https://www.fandom.com/signin?redirect=https%3A%2F%2Felderscrolls.fandom.com%2Fwiki%2FThe_Elder_Scrolls_Wiki',
#  'https://www.fandom.com/register?redirect=https%3A%2F%2Felderscrolls.fandom.com%2Fwiki%2FThe_Elder_Scrolls_Wiki',
#  '//community.fandom.com/wiki/Special:CreateNewWiki',
#  '//elderscrolls.fandom.com',
#  '//elderscrolls.fandom.com',
#  '/wiki/Special:CreatePage',
#  '/wiki/Portal:Online',
#  '/wiki/Quests_(Online)',
#  '/wiki/Main_Quest_(Online)',
#  '/wiki/Aldmeri_Dominion_Quests',
#  '/wiki/Daggerfall_Covenant_Quests',
#  '/wiki/Ebonheart_Pact_Quests',
#  '/wiki/Category:Online:_Side_Quests',
#  '/wiki/Alliances',
#  '/wiki/Aldmeri_Dominion_(Online)',
#  '/wiki/Daggerfall_Covenant',
#  '/wiki/Ebonheart_Pact',
#  '/wiki/Classes_(Online)',
#  '/wiki/Dragonknight',
#  '/wiki/Nightblade_(Online)',
#  '/wiki/Sorcerer_(Online)',
#  '/wiki/Templar',
#  '/wiki/Warden',
#  '/wiki/Necromancer_(Online)',
#  '/wiki/Races_(Online)',
#  '/wiki/Altmer_(Online)',
#  '/wiki/Argonian_(Online)',
#  '/wiki/Bosmer_(Online)',
#  '/wiki/Breton_(Online)',
#  '/wiki/Dunmer_(Online)',
#  '/wiki/Imperial_(Online)',
#  '/wiki/Khajiit_(Online)',
#  '/wiki/Nord_(Online)',
#  '/wiki/Orsimer_(Online)',
#  '/wiki/Redguard_(Online)',
#  '/wiki/Locations_(Online)',
#  '/wiki/Regions_(Online)',
#  '/wiki/Category:Online:_Realms',
#  '/wiki/Category:Online:_Cities',
#  '/wiki/Category:Online:_Delves',
#  '/wiki/Category:Online:_Dungeons',
#  '/wiki/Category:Online:_Dark_Anchors',
#  '/wiki/Wayshrines_(Online)',
#  '/wiki/Category:Online:_Unmarked_Locations',
#  '/wiki/Category:Online:_Gameplay',
#  '/wiki/Combat_(Online)',
#  '/wiki/Skills_(Online)',
#  '/wiki/Ultimate_Skills',
#  '/wiki/Synergy',
#  '/wiki/Finesse',
#  '/wiki/Crafting_(Online)',
#  '/wiki/The_Elder_Scrolls_Online#Expansion packs',
#  '/wiki/The_Elder_Scrolls_Online:_Morrowind',
#  '/wiki/The_Elder_Scrolls_Online:_Summerset',
#  '/wiki/The_Elder_Scrolls_Online:_Elsweyr',
#  '/wiki/The_Elder_Scrolls_Online:_Greymoor',
#  '/wiki/Category:Online:_Official_plug-ins',
#  '/wiki/ESO_Plus',
#  '/wiki/Crown_Store',
#  '/wiki/Portal:Skyrim',
#  '/wiki/Quests_(Skyrim)',
#  '/wiki/Main_Quest_(Skyrim)',
#  '/wiki/Daedric_Quests_(Skyrim)',
#  '/wiki/Dark_Brotherhood_(Skyrim)#Dark Brotherhood quests',
#  '/wiki/College_of_Winterhold#Quests',
#  '/wiki/The_Companions#Quests',
#  '/wiki/Thieves_Guild_(Skyrim)#Quests',
#  '/wiki/Quests_(Skyrim)',
#  '/wiki/Category:Skyrim:_Characters',
#  '/wiki/Races_(Skyrim)',
#  '/wiki/Skills_(Skyrim)',
#  '/wiki/Vampirism_(Skyrim)',
#  '/wiki/Lycanthropy_(Skyrim)',
#  '/wiki/Dragon_Shouts',
#  '/wiki/Abilities_(Skyrim)',
#  '/wiki/Powers',
#  '/wiki/Category:Skyrim:_Gameplay',
#  '/wiki/Alchemy_(Skyrim)',
#  '/wiki/Enchanting_(Skyrim)',
#  '/wiki/Smithing_(Skyrim)',
#  '/wiki/Followers_(Skyrim)',
#  '/wiki/Trainers_(Skyrim)',
#  '/wiki/Marriage',
#  '/wiki/Perks',
#  '/wiki/Controls_(Skyrim)',
#  '/wiki/Category:Skyrim:_Gameplay',
#  '/wiki/Map_(Skyrim)',
#  '/wiki/Holds',
#  '/wiki/Locations_(Skyrim)',
#  '/wiki/Daedric_Shrines_(Skyrim)',
#  '/wiki/Dragons_(Skyrim)',
#  '/wiki/Creatures_(Skyrim)',
#  '/wiki/Factions_(Skyrim)',
#  '/wiki/Category:Skyrim:_Items',
#  '/wiki/Weapons_(Skyrim)',
#  '/wiki/Armor_(Skyrim)',
#  '/wiki/Daedric_Artifacts_(Skyrim)',
#  '/wiki/Quest_Items_(Skyrim)',
#  '/wiki/Category:Skyrim:_Unobtainable_Items',
#  '/wiki/Category:Skyrim:_Gameplay',
#  '/wiki/Console_Commands_(Skyrim)',
#  '/wiki/Random_Encounters_(Skyrim)',
#  '/wiki/Easter_Eggs_(Skyrim)',
#  '/wiki/Enchantment_Modifiers',
#  '/wiki/Official_Add-ons_(Skyrim)',
#  '/wiki/The_Elder_Scrolls_V:_Dawnguard',
#  '/wiki/The_Elder_Scrolls_V:_Hearthfire',
#  '/wiki/The_Elder_Scrolls_V:_Dragonborn',
#  '/wiki/The_Elder_Scrolls_V:_Skyrim_Special_Edition',
#  '/wiki/Creation_Club',
#  '/wiki/The_Elder_Scrolls',
#  '/wiki/The_Elder_Scrolls:_Arena',
#  '/wiki/The_Elder_Scrolls_II:_Daggerfall',
#  '/wiki/The_Elder_Scrolls_III:_Morrowind',
#  '/wiki/The_Elder_Scrolls_III:_Tribunal',
#  '/wiki/The_Elder_Scrolls_III:_Bloodmoon',
#  '/wiki/The_Elder_Scrolls_IV:_Oblivion',
#  '/wiki/The_Elder_Scrolls_Travels:_Oblivion_(Mobile)',
#  '/wiki/The_Elder_Scrolls_IV:_Shivering_Isles',
#  '/wiki/The_Elder_Scrolls_IV:_Knights_of_the_Nine',
#  '/wiki/The_Elder_Scrolls_V:_Skyrim',
#  '/wiki/The_Elder_Scrolls_V:_Dawnguard',
#  '/wiki/The_Elder_Scrolls_V:_Hearthfire',
#  '/wiki/The_Elder_Scrolls_V:_Dragonborn',
#  '/wiki/Category:Games',
#  '/wiki/An_Elder_Scrolls_Legend:_Battlespire',
#  '/wiki/The_Elder_Scrolls_Adventures:_Redguard',
#  '/wiki/The_Elder_Scrolls_Travels:_Dawnstar',
#  '/wiki/The_Elder_Scrolls_Travels:_Stormhold',
#  '/wiki/The_Elder_Scrolls_Travels:_Shadowkey',
#  '/wiki/The_Elder_Scrolls:_Legends',
#  '/wiki/The_Elder_Scrolls:_Blades',
#  '/wiki/The_Elder_Scrolls_Wiki/Portal/Lore',
#  '/wiki/Category:Lore:_Events',
#  '/wiki/Category:Lore:_Characters',
#  '/wiki/Category:Lore:_Factions',
#  '/wiki/Category:Lore:_Locations',
#  '/wiki/Category:Lore:_Concepts',
#  '/wiki/The_Elder_Scrolls_Wiki:Community_Portal',
#  '/wiki/Help:Contents',
#  '/wiki/Help:Contributing',
#  '/wiki/Help:Editing',
#  '/wiki/Help:Getting_Technical',
#  '/wiki/Help:Talk_page',
#  '/wiki/Help:Managing_Your_Account',
#  '/wiki/Help:Index',
#  '/wiki/The_Elder_Scrolls_Wiki:Sandbox',
#  '/wiki/The_Elder_Scrolls_Wiki:Staff',
#  '/wiki/The_Elder_Scrolls_Wiki:Administrators',
#  '/wiki/The_Elder_Scrolls_Wiki:Patrollers',
#  '/wiki/The_Elder_Scrolls_Wiki:Moderators',
#  '/wiki/The_Elder_Scrolls_Wiki:Discord_Moderators',
#  '/wiki/The_Elder_Scrolls_Wiki:News_Team',
#  '/wiki/The_Elder_Scrolls_Wiki:Bots',
#  '/wiki/Category:Policies',
#  '/wiki/The_Elder_Scrolls_Wiki:Policies_and_Guidelines',
#  '/wiki/The_Elder_Scrolls_Wiki:Style_and_Formatting',
#  '/wiki/The_Elder_Scrolls_Wiki:Neutral_point_of_view',
#  '/wiki/The_Elder_Scrolls_Wiki:Blocking_policy',
#  '/wiki/The_Elder_Scrolls_Wiki:Consensus',
#  '/wiki/The_Elder_Scrolls_Wiki:Media',
#  '/wiki/The_Elder_Scrolls_Wiki:Blog_policy',
#  '/wiki/The_Elder_Scrolls_Wiki:Discussions',
#  '/wiki/The_Elder_Scrolls_Wiki:Chat',
#  '/wiki/Blog:Recent_posts',
#  '/wiki/The_Elder_Scrolls_Wiki:News',
#  '/wiki/The_Elder_Scrolls_Wiki:Weekly_Updates',
#  '/wiki/The_Elder_Scrolls_Wiki:Member_of_the_Month',
#  '/wiki/The_Elder_Scrolls_Wiki:Featured_Articles',
#  '/wiki/The_Elder_Scrolls_Wiki:Good_Articles',
#  '/wiki/The_Elder_Scrolls_Wiki:Comprehensive_Articles',
#  '/wiki/The_Elder_Scrolls_Wiki:Moot',
#  '/wiki/The_Elder_Scrolls_Wiki:Vandalism_in_progress',
#  '//elderscrolls.fandom.com/wiki/Special:RecentChanges',
#  '//elderscrolls.fandom.com/wiki/Special:Random',
#  '//elderscrolls.fandom.com/wiki/Special:Community',
#  '//elderscrolls.fandom.com/wiki/Special:NewFiles?mediatype=VIDEO&wpFormIdentifier=specialnewimages',
#  '//elderscrolls.fandom.com/wiki/Special:NewFiles',
#  'https://shop.fandom.com/elder-scrolls-ft4866.html',
#  'https://shop.fandom.com/elder-scrolls/home/4866-gf33453.html',
#  'https://shop.fandom.com/elder-scrolls/gaming/4866-gf33533.html',
#  '/f',
#  'https://elderscrolls.fandom.com/be/wiki/',
#  'https://theelderscrolls.fandom.com/cs/wiki/',
#  'https://the-elder-scrolls.fandom.com/da/wiki/',
#  'https://elderscrolls.fandom.com/de/wiki/',
#  'https://elderscrolls.fandom.com/es/wiki/',
#  'https://elderscrollsfinland.fandom.com/fi/wiki/',
#  'https://elderscrolls.fandom.com/fr/wiki/',
#  'https://elderscrolls.fandom.com/hu/wiki/',
#  'https://elderscrolls.fandom.com/hy/wiki/',
#  'https://elderscrolls.fandom.com/id/wiki/',
#  'https://elderscrolls.fandom.com/is/wiki/',
#  'https://elderscrolls.fandom.com/it/wiki/',
#  'https://elderscrolls.fandom.com/ja/wiki/',
#  'https://elderscrolls.fandom.com/nl/wiki/',
#  'https://elderscrolls.fandom.com/no/wiki/',
#  'https://elderscrolls.fandom.com/pl/wiki/',
#  'https://elderscrolls.fandom.com/pt/wiki/',
#  'https://elderscrolls.fandom.com/ru/wiki/',
#  'https://elderscrolls.fandom.com/sv/wiki/',
#  'https://elderscrolls.fandom.com/th/wiki/',
#  'https://elderscrolls.fandom.com/tr/wiki/',
#  'https://elderscrolls.fandom.com/uk/wiki/',
#  'https://elderscrolls.fandom.com/zh/wiki/',
#  '/wiki/The_Elder_Scrolls_Wiki?action=edit',
#  '/wiki/The_Elder_Scrolls_Wiki?action=history',
#  '/wiki/Talk:The_Elder_Scrolls_Wiki',
#  '#',
#  '/wiki/The_Elder_Scrolls',
#  '/wiki/Category:Images',
#  '/wiki/Category:Concept_Art',
#  '/wiki/Category:Books',
#  '/wiki/Category:Audio_File',
#  '/wiki/Category:Videos',
#  '/wiki/Category:Content',
#  '/wiki/Category:Characters',
#  '/wiki/Category:Locations',
#  '/wiki/Category:Quests',
#  '/wiki/Category:Items',
#  '/wiki/Category:Factions',
#  '/wiki/Category:Gameplay',
#  '/wiki/Category:Lore',
#  '/wiki/Category:Real-world_articles',
#  '/wiki/Category:Unlicensed_Texts',
#  '/wiki/Bethesda_Softworks',
#  '/wiki/Tamriel',
#  '/wiki/Magic',
#  '/wiki/Timeline',
#  '/wiki/The_Elder_Scrolls:_Arena',
#  '/wiki/The_Elder_Scrolls_II:_Daggerfall',
#  '/wiki/The_Elder_Scrolls_III:_Morrowind',
#  '/wiki/The_Elder_Scrolls_IV:_Oblivion',
#  '/wiki/The_Elder_Scrolls_V:_Skyrim',
#  '/wiki/The_Elder_Scrolls_Online',
#  '/wiki/The_Elder_Scrolls:_Legends',
#  '/wiki/The_Elder_Scrolls:_Blades',
#  '/wiki/The_Elder_Scrolls:_Blades',
#  '/wiki/The_Elder_Scrolls_V:_Skyrim_Special_Edition',
#  '/wiki/The_Elder_Scrolls_Online:_Greymoor',
#  '/wiki/The_Elder_Scrolls_VI',
#  '/wiki/Portal:Online',
#  '/wiki/Portal:Skyrim',
#  '/wiki/Portal:Oblivion',
#  '/wiki/Portal:Morrowind',
#  '/wiki/Portal:Daggerfall',
#  '/wiki/Portal:Arena',
#  '/wiki/Portal:Online',
#  '/wiki/Portal:Skyrim',
#  '/wiki/Portal:Oblivion',
#  '/wiki/Portal:Morrowind',
#  '/wiki/Portal:Daggerfall',
#  '/wiki/Portal:Arena',
#  '/wiki/User:Stygies_VIII',
#  '/wiki/User:Stygies_VIII',
#  '/wiki/User_blog:Stygies_VIII/Community_Interviews:_LadyNerevar',
#  '/wiki/User_blog:Stygies_VIII/Community_Interviews:_LadyNerevar',
#  '/wiki/User:Amulet_of_Kings',
#  '/wiki/User:Amulet_of_Kings',
#  '/wiki/User_blog:Amulet_of_Kings/ESO:_Gates_of_Oblivion_storyline_and_Blackwood_chapter_revealed',
#  '/wiki/User_blog:Amulet_of_Kings/ESO:_Gates_of_Oblivion_storyline_and_Blackwood_chapter_revealed',
#  '/wiki/User:Amulet_of_Kings',
#  '/wiki/User:Amulet_of_Kings',
#  '/wiki/User_blog:Amulet_of_Kings/ESO:_Markarth_%26_Update_28_Released_on_PC_%26_Mac',
#  '/wiki/User_blog:Amulet_of_Kings/ESO:_Markarth_%26_Update_28_Released_on_PC_%26_Mac',
#  '/wiki/User:Poisoned_apples',
#  '/wiki/User:Poisoned_apples',
#  '/wiki/User_blog:Poisoned_apples/ESO:_Stonethorn_and_Update_27_Released_on_PC,_Mac,_and_Stadia',
#  '/wiki/User_blog:Poisoned_apples/ESO:_Stonethorn_and_Update_27_Released_on_PC,_Mac,_and_Stadia',
#  None,
#  '/wiki/The_Elder_Scrolls_Wiki:News',
#  '/wiki/The_Queen%27s_Decree',
#  '/wiki/Quests_(Summerset)',
#  '/wiki/The_Elder_Scrolls_Online:_Summerset',
#  '/wiki/Vestige',
#  '/wiki/Summerset_(Online)',
#  '/wiki/Queen_Ayrenn_(Online)',
#  '/wiki/Shimmerene_(Online)',
#  '/wiki/Razum-dar_(Online)',
#  '/wiki/The_Queen%27s_Decree',
#  '/wiki/Seyda_Neen_(Online)',
#  '/wiki/Imperials_(Online)',
#  '/wiki/Vvardenfell_(Online)',
#  '/wiki/Bitter_Coast_(Online)',
#  '/wiki/Morrowind_(Online)',
#  '/wiki/Category:ESO_Morrowind:_Location_Images',
#  'https://tes-sandbox.fandom.com/wiki/',
#  'https://tes-mods.fandom.com/wiki/',
#  'https://tes-sandbox.fandom.com/wiki/',
#  'https://assassinscreed.fandom.com/wiki/',
#  'https://callofduty.fandom.com/wiki/',
#  'https://prototype.fandom.com/wiki/',
#  'https://slycooper.fandom.com/wiki/',
#  'https://hitman.fandom.com/wiki/',
#  'https://adventurequest.fandom.com/wiki/',
#  'https://adventurequestworlds.fandom.com/wiki/',
#  'https://arcanum.fandom.com/wiki/',
#  'https://baldursgate.fandom.com/wiki/',
#  'https://biomutant.fandom.com/wiki/',
#  'https://darksouls.fandom.com/wiki/',
#  'https://deusex.fandom.com/wiki/',
#  'https://diablo.fandom.com/wiki/',
#  'https://divinity.fandom.com/wiki/',
#  'https://dragonage.fandom.com/wiki/',
#  'https://dbaddiction.fandom.com/wiki/',
#  'https://dragonsdogma.fandom.com/wiki/',
#  'https://dragonfable.fandom.com/wiki/',
#  'https://dungeonsiege.fandom.com/wiki/',
#  'https://elderscrolls.fandom.com/wiki/',
#  'https://expeditions-viking.fandom.com/wiki/',
#  'https://evergrace.fandom.com/wiki/',
#  'https://fable.fandom.com/wiki/',
#  'https://fallout.fandom.com/wiki/',
#  'https://ftl.fandom.com/wiki/',
#  'https://five-nights-at-freddys-world.fandom.com/wiki/',
#  'https://forhonor.fandom.com/wiki/',
#  'https://tga.fandom.com/wiki/',
#  'https://glitchtale.fandom.com/wiki/',
#  'https://grandchase.fandom.com/wiki/',
#  'https://hyperlightdrifter.fandom.com/wiki/',
#  'https://ibgame.fandom.com/wiki/',
#  'https://indivisible.fandom.com/wiki/',
#  'https://masquerada.fandom.com/wiki/',
#  'https://masseffect.fandom.com/wiki/',
#  'https://mechquest.fandom.com/wiki/',
#  'https://memory-of-eldurim.fandom.com/wiki/',
#  'https://mightandmagic.fandom.com/wiki/',
#  'https://onmyoji.fandom.com/wiki/',
#  'https://oversoul.fandom.com/wiki/',
#  'https://shadowrun.fandom.com/wiki/',
#  'https://spellforce.fandom.com/wiki/',
#  'https://storiesgames.fandom.com/wiki/',
#  'https://summonerswar.fandom.com/wiki/',
#  'https://talesoferin.fandom.com/wiki/',
#  'https://tothemoon.fandom.com/wiki/',
#  'https://thedivision.fandom.com/wiki/',
#  'https://torment.fandom.com/wiki/',
#  'https://ultima.fandom.com/wiki/',
#  'https://undertale.fandom.com/wiki/',
#  'https://warpforce.fandom.com/wiki/',
#  'https://wasteland.fandom.com/wiki/',
#  'https://witcher-games.fandom.com/wiki/',
#  'https://community.fandom.com/wiki/Template_talk:FooterRPGGames',
#  '/wiki/Special:UserLogin',
#  '/wiki/Special:AllPages',
#  '/wiki/The_Elder_Scrolls_Wiki:A',
#  'https://community.fandom.com/wiki/Help:Contents',
#  '/wiki/The_Elder_Scrolls_Wiki:PAG',
#  '/wiki/Category:Lore',
#  '/wiki/Category:Stub',
#  '/wiki/The_Elder_Scrolls_Wiki:VIP',
#  '/wiki/Special:RecentChanges',
#  'https://static.wikia.nocookie.net/elderscrolls/images/8/89/Wiki-wordmark.png/revision/latest?cb=20210112111029',
#  'https://www.imperial-library.info/content/about-us',
#  '/wiki/User_blog:Stygies_VIII/Community_Interviews:_LadyNerevar',
#  'https://twitter.com/TES_Wikia',
#  'https://elderscrolls.fandom.com/d',
#  'https://elderscrolls.fandom.com/wiki/The_Elder_Scrolls_Wiki?oldid=3121405',
#  '/wiki/Special:Categories',
#  '/wiki/Category:The_Elder_Scrolls_Wiki',
#  'https://elderscrolls.fandom.com/be/wiki/',
#  'https://theelderscrolls.fandom.com/cs/wiki/',
#  'https://the-elder-scrolls.fandom.com/da/wiki/',
#  'https://elderscrolls.fandom.com/de/wiki/',
#  'https://elderscrolls.fandom.com/es/wiki/',
#  'https://elderscrollsfinland.fandom.com/fi/wiki/',
#  'https://elderscrolls.fandom.com/fr/wiki/',
#  'https://elderscrolls.fandom.com/hu/wiki/',
#  'https://elderscrolls.fandom.com/hy/wiki/',
#  'https://elderscrolls.fandom.com/id/wiki/',
#  'https://elderscrolls.fandom.com/is/wiki/',
#  'https://elderscrolls.fandom.com/it/wiki/',
#  'https://elderscrolls.fandom.com/ja/wiki/',
#  'https://elderscrolls.fandom.com/nl/wiki/',
#  'https://elderscrolls.fandom.com/no/wiki/',
#  'https://elderscrolls.fandom.com/pl/wiki/',
#  'https://elderscrolls.fandom.com/pt/wiki/',
#  'https://elderscrolls.fandom.com/ru/wiki/',
#  'https://elderscrolls.fandom.com/sv/wiki/',
#  'https://elderscrolls.fandom.com/th/wiki/',
#  'https://elderscrolls.fandom.com/tr/wiki/',
#  'https://elderscrolls.fandom.com/uk/wiki/',
#  'https://elderscrolls.fandom.com/zh/wiki/',
#  'https://www.fandom.com/licensing',
#  '/wiki/Marriage_(Skyrim)',
#  '/wiki/Stones_of_Barenziah',
#  '/wiki/Console_Commands_(Skyrim)',
#  'http://bit.ly/en-spotlight-universalconquest',
#  'https://letsgoluna.fandom.com/wiki/Let%27s_Go_Luna!_Wiki',
#  'http://bit.ly/fandomshop1',
#  'https://bit.ly/WBEmailCap',
#  'https://bit.ly/PPlusWikiBar',
#  '#',
#  'https://www.fandom.com/',
#  'https://www.fandom.com/',
#  'https://www.gamepedia.com/',
#  'https://www.dndbeyond.com/',
#  'https://www.cortexrpg.com/',
#  'https://www.muthead.com/',
#  'https://www.futhead.com/',
#  'https://www.facebook.com/getfandom',
#  'https://twitter.com/getfandom',
#  'https://www.youtube.com/fandomentertainment',
#  'https://www.instagram.com/getfandom/',
#  'https://www.linkedin.com/company/157252',
#  'https://www.fandom.com/about',
#  'https://www.fandom.com/careers',
#  'https://www.fandom.com/press',
#  'https://www.fandom.com/about#contact',
#  'https://www.fandom.com/terms-of-use',
#  'https://www.fandom.com/privacy-policy',
#  '//community.fandom.com/Sitemap',
#  '/wiki/Local_Sitemap',
#  '//community.fandom.com/wiki/Community_Central',
#  'https://fandom.zendesk.com/',
#  '//community.fandom.com/wiki/Help:Contents',
#  'https://www.fandom.com/do-not-sell-my-info',
#  'https://www.fandom.com/mediakit',
#  'https://www.fandom.com/mediakit#contact',
#  'https://apps.apple.com/us/app/fandom-videos-news-reviews/id1230063803',
#  'https://play.google.com/store/apps/details?id=com.fandom.app&referrer=utm_source%3Dwikia%26utm_medium%3Dglobalfooter',
#  'https://apps.apple.com/us/app/id1501810129',
#  'https://play.google.com/store/apps/details?id=com.fandom.playercompanion&referrer=utm_source%3Dwikia%26utm_medium%3Dglobalfooter',
#  '']

# %%
tag_list = [t[6:] for t in tag_list if (t) and (t.startswith('/wiki/'))]
tag_list
# Out:
# ['Special:CreatePage',
#  'Portal:Online',
#  'Quests_(Online)',
#  'Main_Quest_(Online)',
#  'Aldmeri_Dominion_Quests',
#  'Daggerfall_Covenant_Quests',
#  'Ebonheart_Pact_Quests',
#  'Category:Online:_Side_Quests',
#  'Alliances',
#  'Aldmeri_Dominion_(Online)',
#  'Daggerfall_Covenant',
#  'Ebonheart_Pact',
#  'Classes_(Online)',
#  'Dragonknight',
#  'Nightblade_(Online)',
#  'Sorcerer_(Online)',
#  'Templar',
#  'Warden',
#  'Necromancer_(Online)',
#  'Races_(Online)',
#  'Altmer_(Online)',
#  'Argonian_(Online)',
#  'Bosmer_(Online)',
#  'Breton_(Online)',
#  'Dunmer_(Online)',
#  'Imperial_(Online)',
#  'Khajiit_(Online)',
#  'Nord_(Online)',
#  'Orsimer_(Online)',
#  'Redguard_(Online)',
#  'Locations_(Online)',
#  'Regions_(Online)',
#  'Category:Online:_Realms',
#  'Category:Online:_Cities',
#  'Category:Online:_Delves',
#  'Category:Online:_Dungeons',
#  'Category:Online:_Dark_Anchors',
#  'Wayshrines_(Online)',
#  'Category:Online:_Unmarked_Locations',
#  'Category:Online:_Gameplay',
#  'Combat_(Online)',
#  'Skills_(Online)',
#  'Ultimate_Skills',
#  'Synergy',
#  'Finesse',
#  'Crafting_(Online)',
#  'The_Elder_Scrolls_Online#Expansion packs',
#  'The_Elder_Scrolls_Online:_Morrowind',
#  'The_Elder_Scrolls_Online:_Summerset',
#  'The_Elder_Scrolls_Online:_Elsweyr',
#  'The_Elder_Scrolls_Online:_Greymoor',
#  'Category:Online:_Official_plug-ins',
#  'ESO_Plus',
#  'Crown_Store',
#  'Portal:Skyrim',
#  'Quests_(Skyrim)',
#  'Main_Quest_(Skyrim)',
#  'Daedric_Quests_(Skyrim)',
#  'Dark_Brotherhood_(Skyrim)#Dark Brotherhood quests',
#  'College_of_Winterhold#Quests',
#  'The_Companions#Quests',
#  'Thieves_Guild_(Skyrim)#Quests',
#  'Quests_(Skyrim)',
#  'Category:Skyrim:_Characters',
#  'Races_(Skyrim)',
#  'Skills_(Skyrim)',
#  'Vampirism_(Skyrim)',
#  'Lycanthropy_(Skyrim)',
#  'Dragon_Shouts',
#  'Abilities_(Skyrim)',
#  'Powers',
#  'Category:Skyrim:_Gameplay',
#  'Alchemy_(Skyrim)',
#  'Enchanting_(Skyrim)',
#  'Smithing_(Skyrim)',
#  'Followers_(Skyrim)',
#  'Trainers_(Skyrim)',
#  'Marriage',
#  'Perks',
#  'Controls_(Skyrim)',
#  'Category:Skyrim:_Gameplay',
#  'Map_(Skyrim)',
#  'Holds',
#  'Locations_(Skyrim)',
#  'Daedric_Shrines_(Skyrim)',
#  'Dragons_(Skyrim)',
#  'Creatures_(Skyrim)',
#  'Factions_(Skyrim)',
#  'Category:Skyrim:_Items',
#  'Weapons_(Skyrim)',
#  'Armor_(Skyrim)',
#  'Daedric_Artifacts_(Skyrim)',
#  'Quest_Items_(Skyrim)',
#  'Category:Skyrim:_Unobtainable_Items',
#  'Category:Skyrim:_Gameplay',
#  'Console_Commands_(Skyrim)',
#  'Random_Encounters_(Skyrim)',
#  'Easter_Eggs_(Skyrim)',
#  'Enchantment_Modifiers',
#  'Official_Add-ons_(Skyrim)',
#  'The_Elder_Scrolls_V:_Dawnguard',
#  'The_Elder_Scrolls_V:_Hearthfire',
#  'The_Elder_Scrolls_V:_Dragonborn',
#  'The_Elder_Scrolls_V:_Skyrim_Special_Edition',
#  'Creation_Club',
#  'The_Elder_Scrolls',
#  'The_Elder_Scrolls:_Arena',
#  'The_Elder_Scrolls_II:_Daggerfall',
#  'The_Elder_Scrolls_III:_Morrowind',
#  'The_Elder_Scrolls_III:_Tribunal',
#  'The_Elder_Scrolls_III:_Bloodmoon',
#  'The_Elder_Scrolls_IV:_Oblivion',
#  'The_Elder_Scrolls_Travels:_Oblivion_(Mobile)',
#  'The_Elder_Scrolls_IV:_Shivering_Isles',
#  'The_Elder_Scrolls_IV:_Knights_of_the_Nine',
#  'The_Elder_Scrolls_V:_Skyrim',
#  'The_Elder_Scrolls_V:_Dawnguard',
#  'The_Elder_Scrolls_V:_Hearthfire',
#  'The_Elder_Scrolls_V:_Dragonborn',
#  'Category:Games',
#  'An_Elder_Scrolls_Legend:_Battlespire',
#  'The_Elder_Scrolls_Adventures:_Redguard',
#  'The_Elder_Scrolls_Travels:_Dawnstar',
#  'The_Elder_Scrolls_Travels:_Stormhold',
#  'The_Elder_Scrolls_Travels:_Shadowkey',
#  'The_Elder_Scrolls:_Legends',
#  'The_Elder_Scrolls:_Blades',
#  'The_Elder_Scrolls_Wiki/Portal/Lore',
#  'Category:Lore:_Events',
#  'Category:Lore:_Characters',
#  'Category:Lore:_Factions',
#  'Category:Lore:_Locations',
#  'Category:Lore:_Concepts',
#  'The_Elder_Scrolls_Wiki:Community_Portal',
#  'Help:Contents',
#  'Help:Contributing',
#  'Help:Editing',
#  'Help:Getting_Technical',
#  'Help:Talk_page',
#  'Help:Managing_Your_Account',
#  'Help:Index',
#  'The_Elder_Scrolls_Wiki:Sandbox',
#  'The_Elder_Scrolls_Wiki:Staff',
#  'The_Elder_Scrolls_Wiki:Administrators',
#  'The_Elder_Scrolls_Wiki:Patrollers',
#  'The_Elder_Scrolls_Wiki:Moderators',
#  'The_Elder_Scrolls_Wiki:Discord_Moderators',
#  'The_Elder_Scrolls_Wiki:News_Team',
#  'The_Elder_Scrolls_Wiki:Bots',
#  'Category:Policies',
#  'The_Elder_Scrolls_Wiki:Policies_and_Guidelines',
#  'The_Elder_Scrolls_Wiki:Style_and_Formatting',
#  'The_Elder_Scrolls_Wiki:Neutral_point_of_view',
#  'The_Elder_Scrolls_Wiki:Blocking_policy',
#  'The_Elder_Scrolls_Wiki:Consensus',
#  'The_Elder_Scrolls_Wiki:Media',
#  'The_Elder_Scrolls_Wiki:Blog_policy',
#  'The_Elder_Scrolls_Wiki:Discussions',
#  'The_Elder_Scrolls_Wiki:Chat',
#  'Blog:Recent_posts',
#  'The_Elder_Scrolls_Wiki:News',
#  'The_Elder_Scrolls_Wiki:Weekly_Updates',
#  'The_Elder_Scrolls_Wiki:Member_of_the_Month',
#  'The_Elder_Scrolls_Wiki:Featured_Articles',
#  'The_Elder_Scrolls_Wiki:Good_Articles',
#  'The_Elder_Scrolls_Wiki:Comprehensive_Articles',
#  'The_Elder_Scrolls_Wiki:Moot',
#  'The_Elder_Scrolls_Wiki:Vandalism_in_progress',
#  'The_Elder_Scrolls_Wiki?action=edit',
#  'The_Elder_Scrolls_Wiki?action=history',
#  'Talk:The_Elder_Scrolls_Wiki',
#  'The_Elder_Scrolls',
#  'Category:Images',
#  'Category:Concept_Art',
#  'Category:Books',
#  'Category:Audio_File',
#  'Category:Videos',
#  'Category:Content',
#  'Category:Characters',
#  'Category:Locations',
#  'Category:Quests',
#  'Category:Items',
#  'Category:Factions',
#  'Category:Gameplay',
#  'Category:Lore',
#  'Category:Real-world_articles',
#  'Category:Unlicensed_Texts',
#  'Bethesda_Softworks',
#  'Tamriel',
#  'Magic',
#  'Timeline',
#  'The_Elder_Scrolls:_Arena',
#  'The_Elder_Scrolls_II:_Daggerfall',
#  'The_Elder_Scrolls_III:_Morrowind',
#  'The_Elder_Scrolls_IV:_Oblivion',
#  'The_Elder_Scrolls_V:_Skyrim',
#  'The_Elder_Scrolls_Online',
#  'The_Elder_Scrolls:_Legends',
#  'The_Elder_Scrolls:_Blades',
#  'The_Elder_Scrolls:_Blades',
#  'The_Elder_Scrolls_V:_Skyrim_Special_Edition',
#  'The_Elder_Scrolls_Online:_Greymoor',
#  'The_Elder_Scrolls_VI',
#  'Portal:Online',
#  'Portal:Skyrim',
#  'Portal:Oblivion',
#  'Portal:Morrowind',
#  'Portal:Daggerfall',
#  'Portal:Arena',
#  'Portal:Online',
#  'Portal:Skyrim',
#  'Portal:Oblivion',
#  'Portal:Morrowind',
#  'Portal:Daggerfall',
#  'Portal:Arena',
#  'User:Stygies_VIII',
#  'User:Stygies_VIII',
#  'User_blog:Stygies_VIII/Community_Interviews:_LadyNerevar',
#  'User_blog:Stygies_VIII/Community_Interviews:_LadyNerevar',
#  'User:Amulet_of_Kings',
#  'User:Amulet_of_Kings',
#  'User_blog:Amulet_of_Kings/ESO:_Gates_of_Oblivion_storyline_and_Blackwood_chapter_revealed',
#  'User_blog:Amulet_of_Kings/ESO:_Gates_of_Oblivion_storyline_and_Blackwood_chapter_revealed',
#  'User:Amulet_of_Kings',
#  'User:Amulet_of_Kings',
#  'User_blog:Amulet_of_Kings/ESO:_Markarth_%26_Update_28_Released_on_PC_%26_Mac',
#  'User_blog:Amulet_of_Kings/ESO:_Markarth_%26_Update_28_Released_on_PC_%26_Mac',
#  'User:Poisoned_apples',
#  'User:Poisoned_apples',
#  'User_blog:Poisoned_apples/ESO:_Stonethorn_and_Update_27_Released_on_PC,_Mac,_and_Stadia',
#  'User_blog:Poisoned_apples/ESO:_Stonethorn_and_Update_27_Released_on_PC,_Mac,_and_Stadia',
#  'The_Elder_Scrolls_Wiki:News',
#  'The_Queen%27s_Decree',
#  'Quests_(Summerset)',
#  'The_Elder_Scrolls_Online:_Summerset',
#  'Vestige',
#  'Summerset_(Online)',
#  'Queen_Ayrenn_(Online)',
#  'Shimmerene_(Online)',
#  'Razum-dar_(Online)',
#  'The_Queen%27s_Decree',
#  'Seyda_Neen_(Online)',
#  'Imperials_(Online)',
#  'Vvardenfell_(Online)',
#  'Bitter_Coast_(Online)',
#  'Morrowind_(Online)',
#  'Category:ESO_Morrowind:_Location_Images',
#  'Special:UserLogin',
#  'Special:AllPages',
#  'The_Elder_Scrolls_Wiki:A',
#  'The_Elder_Scrolls_Wiki:PAG',
#  'Category:Lore',
#  'Category:Stub',
#  'The_Elder_Scrolls_Wiki:VIP',
#  'Special:RecentChanges',
#  'User_blog:Stygies_VIII/Community_Interviews:_LadyNerevar',
#  'Special:Categories',
#  'Category:The_Elder_Scrolls_Wiki',
#  'Marriage_(Skyrim)',
#  'Stones_of_Barenziah',
#  'Console_Commands_(Skyrim)',
#  'Local_Sitemap']

# %%
tag_list = [re.sub('_', ' ', t) for t in tag_list]
tag_list
# Out:
# ['Special:CreatePage',
#  'Portal:Online',
#  'Quests (Online)',
#  'Main Quest (Online)',
#  'Aldmeri Dominion Quests',
#  'Daggerfall Covenant Quests',
#  'Ebonheart Pact Quests',
#  'Category:Online: Side Quests',
#  'Alliances',
#  'Aldmeri Dominion (Online)',
#  'Daggerfall Covenant',
#  'Ebonheart Pact',
#  'Classes (Online)',
#  'Dragonknight',
#  'Nightblade (Online)',
#  'Sorcerer (Online)',
#  'Templar',
#  'Warden',
#  'Necromancer (Online)',
#  'Races (Online)',
#  'Altmer (Online)',
#  'Argonian (Online)',
#  'Bosmer (Online)',
#  'Breton (Online)',
#  'Dunmer (Online)',
#  'Imperial (Online)',
#  'Khajiit (Online)',
#  'Nord (Online)',
#  'Orsimer (Online)',
#  'Redguard (Online)',
#  'Locations (Online)',
#  'Regions (Online)',
#  'Category:Online: Realms',
#  'Category:Online: Cities',
#  'Category:Online: Delves',
#  'Category:Online: Dungeons',
#  'Category:Online: Dark Anchors',
#  'Wayshrines (Online)',
#  'Category:Online: Unmarked Locations',
#  'Category:Online: Gameplay',
#  'Combat (Online)',
#  'Skills (Online)',
#  'Ultimate Skills',
#  'Synergy',
#  'Finesse',
#  'Crafting (Online)',
#  'The Elder Scrolls Online#Expansion packs',
#  'The Elder Scrolls Online: Morrowind',
#  'The Elder Scrolls Online: Summerset',
#  'The Elder Scrolls Online: Elsweyr',
#  'The Elder Scrolls Online: Greymoor',
#  'Category:Online: Official plug-ins',
#  'ESO Plus',
#  'Crown Store',
#  'Portal:Skyrim',
#  'Quests (Skyrim)',
#  'Main Quest (Skyrim)',
#  'Daedric Quests (Skyrim)',
#  'Dark Brotherhood (Skyrim)#Dark Brotherhood quests',
#  'College of Winterhold#Quests',
#  'The Companions#Quests',
#  'Thieves Guild (Skyrim)#Quests',
#  'Quests (Skyrim)',
#  'Category:Skyrim: Characters',
#  'Races (Skyrim)',
#  'Skills (Skyrim)',
#  'Vampirism (Skyrim)',
#  'Lycanthropy (Skyrim)',
#  'Dragon Shouts',
#  'Abilities (Skyrim)',
#  'Powers',
#  'Category:Skyrim: Gameplay',
#  'Alchemy (Skyrim)',
#  'Enchanting (Skyrim)',
#  'Smithing (Skyrim)',
#  'Followers (Skyrim)',
#  'Trainers (Skyrim)',
#  'Marriage',
#  'Perks',
#  'Controls (Skyrim)',
#  'Category:Skyrim: Gameplay',
#  'Map (Skyrim)',
#  'Holds',
#  'Locations (Skyrim)',
#  'Daedric Shrines (Skyrim)',
#  'Dragons (Skyrim)',
#  'Creatures (Skyrim)',
#  'Factions (Skyrim)',
#  'Category:Skyrim: Items',
#  'Weapons (Skyrim)',
#  'Armor (Skyrim)',
#  'Daedric Artifacts (Skyrim)',
#  'Quest Items (Skyrim)',
#  'Category:Skyrim: Unobtainable Items',
#  'Category:Skyrim: Gameplay',
#  'Console Commands (Skyrim)',
#  'Random Encounters (Skyrim)',
#  'Easter Eggs (Skyrim)',
#  'Enchantment Modifiers',
#  'Official Add-ons (Skyrim)',
#  'The Elder Scrolls V: Dawnguard',
#  'The Elder Scrolls V: Hearthfire',
#  'The Elder Scrolls V: Dragonborn',
#  'The Elder Scrolls V: Skyrim Special Edition',
#  'Creation Club',
#  'The Elder Scrolls',
#  'The Elder Scrolls: Arena',
#  'The Elder Scrolls II: Daggerfall',
#  'The Elder Scrolls III: Morrowind',
#  'The Elder Scrolls III: Tribunal',
#  'The Elder Scrolls III: Bloodmoon',
#  'The Elder Scrolls IV: Oblivion',
#  'The Elder Scrolls Travels: Oblivion (Mobile)',
#  'The Elder Scrolls IV: Shivering Isles',
#  'The Elder Scrolls IV: Knights of the Nine',
#  'The Elder Scrolls V: Skyrim',
#  'The Elder Scrolls V: Dawnguard',
#  'The Elder Scrolls V: Hearthfire',
#  'The Elder Scrolls V: Dragonborn',
#  'Category:Games',
#  'An Elder Scrolls Legend: Battlespire',
#  'The Elder Scrolls Adventures: Redguard',
#  'The Elder Scrolls Travels: Dawnstar',
#  'The Elder Scrolls Travels: Stormhold',
#  'The Elder Scrolls Travels: Shadowkey',
#  'The Elder Scrolls: Legends',
#  'The Elder Scrolls: Blades',
#  'The Elder Scrolls Wiki/Portal/Lore',
#  'Category:Lore: Events',
#  'Category:Lore: Characters',
#  'Category:Lore: Factions',
#  'Category:Lore: Locations',
#  'Category:Lore: Concepts',
#  'The Elder Scrolls Wiki:Community Portal',
#  'Help:Contents',
#  'Help:Contributing',
#  'Help:Editing',
#  'Help:Getting Technical',
#  'Help:Talk page',
#  'Help:Managing Your Account',
#  'Help:Index',
#  'The Elder Scrolls Wiki:Sandbox',
#  'The Elder Scrolls Wiki:Staff',
#  'The Elder Scrolls Wiki:Administrators',
#  'The Elder Scrolls Wiki:Patrollers',
#  'The Elder Scrolls Wiki:Moderators',
#  'The Elder Scrolls Wiki:Discord Moderators',
#  'The Elder Scrolls Wiki:News Team',
#  'The Elder Scrolls Wiki:Bots',
#  'Category:Policies',
#  'The Elder Scrolls Wiki:Policies and Guidelines',
#  'The Elder Scrolls Wiki:Style and Formatting',
#  'The Elder Scrolls Wiki:Neutral point of view',
#  'The Elder Scrolls Wiki:Blocking policy',
#  'The Elder Scrolls Wiki:Consensus',
#  'The Elder Scrolls Wiki:Media',
#  'The Elder Scrolls Wiki:Blog policy',
#  'The Elder Scrolls Wiki:Discussions',
#  'The Elder Scrolls Wiki:Chat',
#  'Blog:Recent posts',
#  'The Elder Scrolls Wiki:News',
#  'The Elder Scrolls Wiki:Weekly Updates',
#  'The Elder Scrolls Wiki:Member of the Month',
#  'The Elder Scrolls Wiki:Featured Articles',
#  'The Elder Scrolls Wiki:Good Articles',
#  'The Elder Scrolls Wiki:Comprehensive Articles',
#  'The Elder Scrolls Wiki:Moot',
#  'The Elder Scrolls Wiki:Vandalism in progress',
#  'The Elder Scrolls Wiki?action=edit',
#  'The Elder Scrolls Wiki?action=history',
#  'Talk:The Elder Scrolls Wiki',
#  'The Elder Scrolls',
#  'Category:Images',
#  'Category:Concept Art',
#  'Category:Books',
#  'Category:Audio File',
#  'Category:Videos',
#  'Category:Content',
#  'Category:Characters',
#  'Category:Locations',
#  'Category:Quests',
#  'Category:Items',
#  'Category:Factions',
#  'Category:Gameplay',
#  'Category:Lore',
#  'Category:Real-world articles',
#  'Category:Unlicensed Texts',
#  'Bethesda Softworks',
#  'Tamriel',
#  'Magic',
#  'Timeline',
#  'The Elder Scrolls: Arena',
#  'The Elder Scrolls II: Daggerfall',
#  'The Elder Scrolls III: Morrowind',
#  'The Elder Scrolls IV: Oblivion',
#  'The Elder Scrolls V: Skyrim',
#  'The Elder Scrolls Online',
#  'The Elder Scrolls: Legends',
#  'The Elder Scrolls: Blades',
#  'The Elder Scrolls: Blades',
#  'The Elder Scrolls V: Skyrim Special Edition',
#  'The Elder Scrolls Online: Greymoor',
#  'The Elder Scrolls VI',
#  'Portal:Online',
#  'Portal:Skyrim',
#  'Portal:Oblivion',
#  'Portal:Morrowind',
#  'Portal:Daggerfall',
#  'Portal:Arena',
#  'Portal:Online',
#  'Portal:Skyrim',
#  'Portal:Oblivion',
#  'Portal:Morrowind',
#  'Portal:Daggerfall',
#  'Portal:Arena',
#  'User:Stygies VIII',
#  'User:Stygies VIII',
#  'User blog:Stygies VIII/Community Interviews: LadyNerevar',
#  'User blog:Stygies VIII/Community Interviews: LadyNerevar',
#  'User:Amulet of Kings',
#  'User:Amulet of Kings',
#  'User blog:Amulet of Kings/ESO: Gates of Oblivion storyline and Blackwood chapter revealed',
#  'User blog:Amulet of Kings/ESO: Gates of Oblivion storyline and Blackwood chapter revealed',
#  'User:Amulet of Kings',
#  'User:Amulet of Kings',
#  'User blog:Amulet of Kings/ESO: Markarth %26 Update 28 Released on PC %26 Mac',
#  'User blog:Amulet of Kings/ESO: Markarth %26 Update 28 Released on PC %26 Mac',
#  'User:Poisoned apples',
#  'User:Poisoned apples',
#  'User blog:Poisoned apples/ESO: Stonethorn and Update 27 Released on PC, Mac, and Stadia',
#  'User blog:Poisoned apples/ESO: Stonethorn and Update 27 Released on PC, Mac, and Stadia',
#  'The Elder Scrolls Wiki:News',
#  'The Queen%27s Decree',
#  'Quests (Summerset)',
#  'The Elder Scrolls Online: Summerset',
#  'Vestige',
#  'Summerset (Online)',
#  'Queen Ayrenn (Online)',
#  'Shimmerene (Online)',
#  'Razum-dar (Online)',
#  'The Queen%27s Decree',
#  'Seyda Neen (Online)',
#  'Imperials (Online)',
#  'Vvardenfell (Online)',
#  'Bitter Coast (Online)',
#  'Morrowind (Online)',
#  'Category:ESO Morrowind: Location Images',
#  'Special:UserLogin',
#  'Special:AllPages',
#  'The Elder Scrolls Wiki:A',
#  'The Elder Scrolls Wiki:PAG',
#  'Category:Lore',
#  'Category:Stub',
#  'The Elder Scrolls Wiki:VIP',
#  'Special:RecentChanges',
#  'User blog:Stygies VIII/Community Interviews: LadyNerevar',
#  'Special:Categories',
#  'Category:The Elder Scrolls Wiki',
#  'Marriage (Skyrim)',
#  'Stones of Barenziah',
#  'Console Commands (Skyrim)',
#  'Local Sitemap']

# %%
tag_list = list(set(tag_list))
tag_list
# Out:
# ['Portal:Daggerfall',
#  'Category:Lore: Factions',
#  'Category:Items',
#  'Breton (Online)',
#  'Bethesda Softworks',
#  'Marriage',
#  'The Elder Scrolls IV: Shivering Isles',
#  'Crown Store',
#  'Category:Skyrim: Unobtainable Items',
#  'The Elder Scrolls Wiki:Vandalism in progress',
#  'The Elder Scrolls Online',
#  'Imperial (Online)',
#  'Followers (Skyrim)',
#  'User blog:Amulet of Kings/ESO: Markarth %26 Update 28 Released on PC %26 Mac',
#  'Races (Online)',
#  'Synergy',
#  'Altmer (Online)',
#  'The Elder Scrolls III: Morrowind',
#  'Nord (Online)',
#  'The Queen%27s Decree',
#  'Dragon Shouts',
#  'Category:The Elder Scrolls Wiki',
#  'Help:Editing',
#  'Help:Talk page',
#  'The Elder Scrolls Wiki:Chat',
#  'Category:Online: Cities',
#  'Category:Content',
#  'Sorcerer (Online)',
#  'Races (Skyrim)',
#  'Skills (Skyrim)',
#  'Creation Club',
#  'The Elder Scrolls: Blades',
#  'The Elder Scrolls Wiki:News',
#  'The Elder Scrolls Wiki:Style and Formatting',
#  'Quests (Summerset)',
#  'Map (Skyrim)',
#  'Dragons (Skyrim)',
#  'Category:Games',
#  'Enchanting (Skyrim)',
#  'Category:Videos',
#  'Category:Lore',
#  'Alliances',
#  'Daedric Shrines (Skyrim)',
#  'The Elder Scrolls Online: Summerset',
#  'Help:Managing Your Account',
#  'Locations (Online)',
#  'The Elder Scrolls V: Hearthfire',
#  'Wayshrines (Online)',
#  'Weapons (Skyrim)',
#  'User:Poisoned apples',
#  'Portal:Online',
#  'Help:Contents',
#  'The Elder Scrolls Wiki:Comprehensive Articles',
#  'The Elder Scrolls II: Daggerfall',
#  'Shimmerene (Online)',
#  'The Elder Scrolls Online#Expansion packs',
#  'Powers',
#  'Category:Factions',
#  'Aldmeri Dominion Quests',
#  'The Elder Scrolls',
#  'Special:CreatePage',
#  'Finesse',
#  'Khajiit (Online)',
#  'Factions (Skyrim)',
#  'The Elder Scrolls Wiki:Member of the Month',
#  'Daedric Artifacts (Skyrim)',
#  'Controls (Skyrim)',
#  'Enchantment Modifiers',
#  'Bitter Coast (Online)',
#  'Special:Categories',
#  'The Elder Scrolls Wiki:Moot',
#  'Combat (Online)',
#  'Lycanthropy (Skyrim)',
#  'The Elder Scrolls Wiki:Media',
#  'Category:Policies',
#  'Locations (Skyrim)',
#  'Category:Online: Dungeons',
#  'Category:Skyrim: Characters',
#  'The Elder Scrolls V: Dragonborn',
#  'The Elder Scrolls Wiki:Discord Moderators',
#  'Help:Contributing',
#  'Holds',
#  'Crafting (Online)',
#  'Abilities (Skyrim)',
#  'Category:Characters',
#  'Category:Gameplay',
#  'The Elder Scrolls Online: Morrowind',
#  'Dunmer (Online)',
#  'ESO Plus',
#  'Easter Eggs (Skyrim)',
#  'Summerset (Online)',
#  'Daedric Quests (Skyrim)',
#  'Category:Quests',
#  'Nightblade (Online)',
#  'Category:Audio File',
#  'Ultimate Skills',
#  'The Elder Scrolls Wiki:Consensus',
#  'Help:Getting Technical',
#  'College of Winterhold#Quests',
#  'Special:UserLogin',
#  'The Elder Scrolls Online: Elsweyr',
#  'Queen Ayrenn (Online)',
#  'Portal:Morrowind',
#  'Skills (Online)',
#  'Armor (Skyrim)',
#  'Argonian (Online)',
#  'The Elder Scrolls V: Skyrim',
#  'User:Stygies VIII',
#  'Marriage (Skyrim)',
#  'The Elder Scrolls Wiki:Moderators',
#  'Category:Skyrim: Gameplay',
#  'Quests (Skyrim)',
#  'The Elder Scrolls V: Skyrim Special Edition',
#  'Alchemy (Skyrim)',
#  'Creatures (Skyrim)',
#  'Console Commands (Skyrim)',
#  'Tamriel',
#  'Vestige',
#  'Necromancer (Online)',
#  'Category:Lore: Locations',
#  'The Elder Scrolls Wiki:Featured Articles',
#  'Category:Online: Gameplay',
#  'Special:AllPages',
#  'The Elder Scrolls Wiki:Neutral point of view',
#  'Portal:Oblivion',
#  'The Elder Scrolls Wiki:Patrollers',
#  'Quests (Online)',
#  'Regions (Online)',
#  'Trainers (Skyrim)',
#  'Redguard (Online)',
#  'Category:Online: Dark Anchors',
#  'Imperials (Online)',
#  'Portal:Skyrim',
#  'Stones of Barenziah',
#  'The Elder Scrolls Wiki:Blog policy',
#  'Vampirism (Skyrim)',
#  'Ebonheart Pact Quests',
#  'Local Sitemap',
#  'Ebonheart Pact',
#  'Blog:Recent posts',
#  'Portal:Arena',
#  'The Elder Scrolls Travels: Stormhold',
#  'Help:Index',
#  'Category:ESO Morrowind: Location Images',
#  'Main Quest (Skyrim)',
#  'Templar',
#  'Razum-dar (Online)',
#  'Special:RecentChanges',
#  'The Elder Scrolls Wiki:News Team',
#  'Timeline',
#  'Category:Unlicensed Texts',
#  'Vvardenfell (Online)',
#  'Aldmeri Dominion (Online)',
#  'Warden',
#  'The Elder Scrolls Wiki:Sandbox',
#  'Official Add-ons (Skyrim)',
#  'The Elder Scrolls Wiki:Weekly Updates',
#  'The Elder Scrolls Travels: Dawnstar',
#  'Category:Online: Official plug-ins',
#  'User blog:Stygies VIII/Community Interviews: LadyNerevar',
#  'The Elder Scrolls Wiki:Bots',
#  'The Elder Scrolls Wiki:Discussions',
#  'Morrowind (Online)',
#  'Category:Books',
#  'The Elder Scrolls Wiki:Blocking policy',
#  'User:Amulet of Kings',
#  'The Elder Scrolls: Arena',
#  'The Elder Scrolls Wiki:Policies and Guidelines',
#  'The Elder Scrolls Wiki:Good Articles',
#  'The Elder Scrolls VI',
#  'Random Encounters (Skyrim)',
#  'Dark Brotherhood (Skyrim)#Dark Brotherhood quests',
#  'The Elder Scrolls Wiki?action=history',
#  'The Elder Scrolls Wiki:Administrators',
#  'Daggerfall Covenant Quests',
#  'The Elder Scrolls V: Dawnguard',
#  'The Elder Scrolls Wiki/Portal/Lore',
#  'Category:Locations',
#  'Magic',
#  'User blog:Amulet of Kings/ESO: Gates of Oblivion storyline and Blackwood chapter revealed',
#  'Quest Items (Skyrim)',
#  'Seyda Neen (Online)',
#  'Thieves Guild (Skyrim)#Quests',
#  'Daggerfall Covenant',
#  'The Elder Scrolls Wiki:Staff',
#  'Orsimer (Online)',
#  'Category:Concept Art',
#  'The Elder Scrolls Wiki:VIP',
#  'Category:Images',
#  'Smithing (Skyrim)',
#  'The Elder Scrolls IV: Knights of the Nine',
#  'Category:Skyrim: Items',
#  'The Elder Scrolls: Legends',
#  'Category:Online: Delves',
#  'The Elder Scrolls Online: Greymoor',
#  'The Elder Scrolls Wiki?action=edit',
#  'Main Quest (Online)',
#  'Classes (Online)',
#  'The Elder Scrolls Adventures: Redguard',
#  'Category:Lore: Concepts',
#  'The Elder Scrolls III: Tribunal',
#  'The Companions#Quests',
#  'The Elder Scrolls Travels: Oblivion (Mobile)',
#  'Category:Lore: Events',
#  'The Elder Scrolls Wiki:Community Portal',
#  'Talk:The Elder Scrolls Wiki',
#  'Dragonknight',
#  'Category:Online: Unmarked Locations',
#  'Category:Real-world articles',
#  'Category:Online: Side Quests',
#  'Bosmer (Online)',
#  'The Elder Scrolls Wiki:PAG',
#  'Category:Stub',
#  'Category:Online: Realms',
#  'The Elder Scrolls IV: Oblivion',
#  'The Elder Scrolls Travels: Shadowkey',
#  'An Elder Scrolls Legend: Battlespire',
#  'The Elder Scrolls III: Bloodmoon',
#  'Category:Lore: Characters',
#  'The Elder Scrolls Wiki:A',
#  'Perks',
#  'User blog:Poisoned apples/ESO: Stonethorn and Update 27 Released on PC, Mac, and Stadia']

# %%
tag_list.sort()
tag_list
# Out:
# ['Abilities (Skyrim)',
#  'Alchemy (Skyrim)',
#  'Aldmeri Dominion (Online)',
#  'Aldmeri Dominion Quests',
#  'Alliances',
#  'Altmer (Online)',
#  'An Elder Scrolls Legend: Battlespire',
#  'Argonian (Online)',
#  'Armor (Skyrim)',
#  'Bethesda Softworks',
#  'Bitter Coast (Online)',
#  'Blog:Recent posts',
#  'Bosmer (Online)',
#  'Breton (Online)',
#  'Category:Audio File',
#  'Category:Books',
#  'Category:Characters',
#  'Category:Concept Art',
#  'Category:Content',
#  'Category:ESO Morrowind: Location Images',
#  'Category:Factions',
#  'Category:Gameplay',
#  'Category:Games',
#  'Category:Images',
#  'Category:Items',
#  'Category:Locations',
#  'Category:Lore',
#  'Category:Lore: Characters',
#  'Category:Lore: Concepts',
#  'Category:Lore: Events',
#  'Category:Lore: Factions',
#  'Category:Lore: Locations',
#  'Category:Online: Cities',
#  'Category:Online: Dark Anchors',
#  'Category:Online: Delves',
#  'Category:Online: Dungeons',
#  'Category:Online: Gameplay',
#  'Category:Online: Official plug-ins',
#  'Category:Online: Realms',
#  'Category:Online: Side Quests',
#  'Category:Online: Unmarked Locations',
#  'Category:Policies',
#  'Category:Quests',
#  'Category:Real-world articles',
#  'Category:Skyrim: Characters',
#  'Category:Skyrim: Gameplay',
#  'Category:Skyrim: Items',
#  'Category:Skyrim: Unobtainable Items',
#  'Category:Stub',
#  'Category:The Elder Scrolls Wiki',
#  'Category:Unlicensed Texts',
#  'Category:Videos',
#  'Classes (Online)',
#  'College of Winterhold#Quests',
#  'Combat (Online)',
#  'Console Commands (Skyrim)',
#  'Controls (Skyrim)',
#  'Crafting (Online)',
#  'Creation Club',
#  'Creatures (Skyrim)',
#  'Crown Store',
#  'Daedric Artifacts (Skyrim)',
#  'Daedric Quests (Skyrim)',
#  'Daedric Shrines (Skyrim)',
#  'Daggerfall Covenant',
#  'Daggerfall Covenant Quests',
#  'Dark Brotherhood (Skyrim)#Dark Brotherhood quests',
#  'Dragon Shouts',
#  'Dragonknight',
#  'Dragons (Skyrim)',
#  'Dunmer (Online)',
#  'ESO Plus',
#  'Easter Eggs (Skyrim)',
#  'Ebonheart Pact',
#  'Ebonheart Pact Quests',
#  'Enchanting (Skyrim)',
#  'Enchantment Modifiers',
#  'Factions (Skyrim)',
#  'Finesse',
#  'Followers (Skyrim)',
#  'Help:Contents',
#  'Help:Contributing',
#  'Help:Editing',
#  'Help:Getting Technical',
#  'Help:Index',
#  'Help:Managing Your Account',
#  'Help:Talk page',
#  'Holds',
#  'Imperial (Online)',
#  'Imperials (Online)',
#  'Khajiit (Online)',
#  'Local Sitemap',
#  'Locations (Online)',
#  'Locations (Skyrim)',
#  'Lycanthropy (Skyrim)',
#  'Magic',
#  'Main Quest (Online)',
#  'Main Quest (Skyrim)',
#  'Map (Skyrim)',
#  'Marriage',
#  'Marriage (Skyrim)',
#  'Morrowind (Online)',
#  'Necromancer (Online)',
#  'Nightblade (Online)',
#  'Nord (Online)',
#  'Official Add-ons (Skyrim)',
#  'Orsimer (Online)',
#  'Perks',
#  'Portal:Arena',
#  'Portal:Daggerfall',
#  'Portal:Morrowind',
#  'Portal:Oblivion',
#  'Portal:Online',
#  'Portal:Skyrim',
#  'Powers',
#  'Queen Ayrenn (Online)',
#  'Quest Items (Skyrim)',
#  'Quests (Online)',
#  'Quests (Skyrim)',
#  'Quests (Summerset)',
#  'Races (Online)',
#  'Races (Skyrim)',
#  'Random Encounters (Skyrim)',
#  'Razum-dar (Online)',
#  'Redguard (Online)',
#  'Regions (Online)',
#  'Seyda Neen (Online)',
#  'Shimmerene (Online)',
#  'Skills (Online)',
#  'Skills (Skyrim)',
#  'Smithing (Skyrim)',
#  'Sorcerer (Online)',
#  'Special:AllPages',
#  'Special:Categories',
#  'Special:CreatePage',
#  'Special:RecentChanges',
#  'Special:UserLogin',
#  'Stones of Barenziah',
#  'Summerset (Online)',
#  'Synergy',
#  'Talk:The Elder Scrolls Wiki',
#  'Tamriel',
#  'Templar',
#  'The Companions#Quests',
#  'The Elder Scrolls',
#  'The Elder Scrolls Adventures: Redguard',
#  'The Elder Scrolls II: Daggerfall',
#  'The Elder Scrolls III: Bloodmoon',
#  'The Elder Scrolls III: Morrowind',
#  'The Elder Scrolls III: Tribunal',
#  'The Elder Scrolls IV: Knights of the Nine',
#  'The Elder Scrolls IV: Oblivion',
#  'The Elder Scrolls IV: Shivering Isles',
#  'The Elder Scrolls Online',
#  'The Elder Scrolls Online#Expansion packs',
#  'The Elder Scrolls Online: Elsweyr',
#  'The Elder Scrolls Online: Greymoor',
#  'The Elder Scrolls Online: Morrowind',
#  'The Elder Scrolls Online: Summerset',
#  'The Elder Scrolls Travels: Dawnstar',
#  'The Elder Scrolls Travels: Oblivion (Mobile)',
#  'The Elder Scrolls Travels: Shadowkey',
#  'The Elder Scrolls Travels: Stormhold',
#  'The Elder Scrolls V: Dawnguard',
#  'The Elder Scrolls V: Dragonborn',
#  'The Elder Scrolls V: Hearthfire',
#  'The Elder Scrolls V: Skyrim',
#  'The Elder Scrolls V: Skyrim Special Edition',
#  'The Elder Scrolls VI',
#  'The Elder Scrolls Wiki/Portal/Lore',
#  'The Elder Scrolls Wiki:A',
#  'The Elder Scrolls Wiki:Administrators',
#  'The Elder Scrolls Wiki:Blocking policy',
#  'The Elder Scrolls Wiki:Blog policy',
#  'The Elder Scrolls Wiki:Bots',
#  'The Elder Scrolls Wiki:Chat',
#  'The Elder Scrolls Wiki:Community Portal',
#  'The Elder Scrolls Wiki:Comprehensive Articles',
#  'The Elder Scrolls Wiki:Consensus',
#  'The Elder Scrolls Wiki:Discord Moderators',
#  'The Elder Scrolls Wiki:Discussions',
#  'The Elder Scrolls Wiki:Featured Articles',
#  'The Elder Scrolls Wiki:Good Articles',
#  'The Elder Scrolls Wiki:Media',
#  'The Elder Scrolls Wiki:Member of the Month',
#  'The Elder Scrolls Wiki:Moderators',
#  'The Elder Scrolls Wiki:Moot',
#  'The Elder Scrolls Wiki:Neutral point of view',
#  'The Elder Scrolls Wiki:News',
#  'The Elder Scrolls Wiki:News Team',
#  'The Elder Scrolls Wiki:PAG',
#  'The Elder Scrolls Wiki:Patrollers',
#  'The Elder Scrolls Wiki:Policies and Guidelines',
#  'The Elder Scrolls Wiki:Sandbox',
#  'The Elder Scrolls Wiki:Staff',
#  'The Elder Scrolls Wiki:Style and Formatting',
#  'The Elder Scrolls Wiki:VIP',
#  'The Elder Scrolls Wiki:Vandalism in progress',
#  'The Elder Scrolls Wiki:Weekly Updates',
#  'The Elder Scrolls Wiki?action=edit',
#  'The Elder Scrolls Wiki?action=history',
#  'The Elder Scrolls: Arena',
#  'The Elder Scrolls: Blades',
#  'The Elder Scrolls: Legends',
#  'The Queen%27s Decree',
#  'Thieves Guild (Skyrim)#Quests',
#  'Timeline',
#  'Trainers (Skyrim)',
#  'Ultimate Skills',
#  'User blog:Amulet of Kings/ESO: Gates of Oblivion storyline and Blackwood chapter revealed',
#  'User blog:Amulet of Kings/ESO: Markarth %26 Update 28 Released on PC %26 Mac',
#  'User blog:Poisoned apples/ESO: Stonethorn and Update 27 Released on PC, Mac, and Stadia',
#  'User blog:Stygies VIII/Community Interviews: LadyNerevar',
#  'User:Amulet of Kings',
#  'User:Poisoned apples',
#  'User:Stygies VIII',
#  'Vampirism (Skyrim)',
#  'Vestige',
#  'Vvardenfell (Online)',
#  'Warden',
#  'Wayshrines (Online)',
#  'Weapons (Skyrim)']

# %% [markdown]
# ### Create a filter for unwanted types of articles

# %%
# create a filter for undesired links
filter  = '(%s)' % '|'.join([
    'User:',
    'Blog:',
])
# remove the links that are found in the filter
tag_list = [t for t in tag_list if not re.search(filter, t)]
tag_list
# Out:
# ['Abilities (Skyrim)',
#  'Alchemy (Skyrim)',
#  'Aldmeri Dominion (Online)',
#  'Aldmeri Dominion Quests',
#  'Alliances',
#  'Altmer (Online)',
#  'An Elder Scrolls Legend: Battlespire',
#  'Argonian (Online)',
#  'Armor (Skyrim)',
#  'Bethesda Softworks',
#  'Bitter Coast (Online)',
#  'Bosmer (Online)',
#  'Breton (Online)',
#  'Category:Audio File',
#  'Category:Books',
#  'Category:Characters',
#  'Category:Concept Art',
#  'Category:Content',
#  'Category:ESO Morrowind: Location Images',
#  'Category:Factions',
#  'Category:Gameplay',
#  'Category:Games',
#  'Category:Images',
#  'Category:Items',
#  'Category:Locations',
#  'Category:Lore',
#  'Category:Lore: Characters',
#  'Category:Lore: Concepts',
#  'Category:Lore: Events',
#  'Category:Lore: Factions',
#  'Category:Lore: Locations',
#  'Category:Online: Cities',
#  'Category:Online: Dark Anchors',
#  'Category:Online: Delves',
#  'Category:Online: Dungeons',
#  'Category:Online: Gameplay',
#  'Category:Online: Official plug-ins',
#  'Category:Online: Realms',
#  'Category:Online: Side Quests',
#  'Category:Online: Unmarked Locations',
#  'Category:Policies',
#  'Category:Quests',
#  'Category:Real-world articles',
#  'Category:Skyrim: Characters',
#  'Category:Skyrim: Gameplay',
#  'Category:Skyrim: Items',
#  'Category:Skyrim: Unobtainable Items',
#  'Category:Stub',
#  'Category:The Elder Scrolls Wiki',
#  'Category:Unlicensed Texts',
#  'Category:Videos',
#  'Classes (Online)',
#  'College of Winterhold#Quests',
#  'Combat (Online)',
#  'Console Commands (Skyrim)',
#  'Controls (Skyrim)',
#  'Crafting (Online)',
#  'Creation Club',
#  'Creatures (Skyrim)',
#  'Crown Store',
#  'Daedric Artifacts (Skyrim)',
#  'Daedric Quests (Skyrim)',
#  'Daedric Shrines (Skyrim)',
#  'Daggerfall Covenant',
#  'Daggerfall Covenant Quests',
#  'Dark Brotherhood (Skyrim)#Dark Brotherhood quests',
#  'Dragon Shouts',
#  'Dragonknight',
#  'Dragons (Skyrim)',
#  'Dunmer (Online)',
#  'ESO Plus',
#  'Easter Eggs (Skyrim)',
#  'Ebonheart Pact',
#  'Ebonheart Pact Quests',
#  'Enchanting (Skyrim)',
#  'Enchantment Modifiers',
#  'Factions (Skyrim)',
#  'Finesse',
#  'Followers (Skyrim)',
#  'Help:Contents',
#  'Help:Contributing',
#  'Help:Editing',
#  'Help:Getting Technical',
#  'Help:Index',
#  'Help:Managing Your Account',
#  'Help:Talk page',
#  'Holds',
#  'Imperial (Online)',
#  'Imperials (Online)',
#  'Khajiit (Online)',
#  'Local Sitemap',
#  'Locations (Online)',
#  'Locations (Skyrim)',
#  'Lycanthropy (Skyrim)',
#  'Magic',
#  'Main Quest (Online)',
#  'Main Quest (Skyrim)',
#  'Map (Skyrim)',
#  'Marriage',
#  'Marriage (Skyrim)',
#  'Morrowind (Online)',
#  'Necromancer (Online)',
#  'Nightblade (Online)',
#  'Nord (Online)',
#  'Official Add-ons (Skyrim)',
#  'Orsimer (Online)',
#  'Perks',
#  'Portal:Arena',
#  'Portal:Daggerfall',
#  'Portal:Morrowind',
#  'Portal:Oblivion',
#  'Portal:Online',
#  'Portal:Skyrim',
#  'Powers',
#  'Queen Ayrenn (Online)',
#  'Quest Items (Skyrim)',
#  'Quests (Online)',
#  'Quests (Skyrim)',
#  'Quests (Summerset)',
#  'Races (Online)',
#  'Races (Skyrim)',
#  'Random Encounters (Skyrim)',
#  'Razum-dar (Online)',
#  'Redguard (Online)',
#  'Regions (Online)',
#  'Seyda Neen (Online)',
#  'Shimmerene (Online)',
#  'Skills (Online)',
#  'Skills (Skyrim)',
#  'Smithing (Skyrim)',
#  'Sorcerer (Online)',
#  'Special:AllPages',
#  'Special:Categories',
#  'Special:CreatePage',
#  'Special:RecentChanges',
#  'Special:UserLogin',
#  'Stones of Barenziah',
#  'Summerset (Online)',
#  'Synergy',
#  'Talk:The Elder Scrolls Wiki',
#  'Tamriel',
#  'Templar',
#  'The Companions#Quests',
#  'The Elder Scrolls',
#  'The Elder Scrolls Adventures: Redguard',
#  'The Elder Scrolls II: Daggerfall',
#  'The Elder Scrolls III: Bloodmoon',
#  'The Elder Scrolls III: Morrowind',
#  'The Elder Scrolls III: Tribunal',
#  'The Elder Scrolls IV: Knights of the Nine',
#  'The Elder Scrolls IV: Oblivion',
#  'The Elder Scrolls IV: Shivering Isles',
#  'The Elder Scrolls Online',
#  'The Elder Scrolls Online#Expansion packs',
#  'The Elder Scrolls Online: Elsweyr',
#  'The Elder Scrolls Online: Greymoor',
#  'The Elder Scrolls Online: Morrowind',
#  'The Elder Scrolls Online: Summerset',
#  'The Elder Scrolls Travels: Dawnstar',
#  'The Elder Scrolls Travels: Oblivion (Mobile)',
#  'The Elder Scrolls Travels: Shadowkey',
#  'The Elder Scrolls Travels: Stormhold',
#  'The Elder Scrolls V: Dawnguard',
#  'The Elder Scrolls V: Dragonborn',
#  'The Elder Scrolls V: Hearthfire',
#  'The Elder Scrolls V: Skyrim',
#  'The Elder Scrolls V: Skyrim Special Edition',
#  'The Elder Scrolls VI',
#  'The Elder Scrolls Wiki/Portal/Lore',
#  'The Elder Scrolls Wiki:A',
#  'The Elder Scrolls Wiki:Administrators',
#  'The Elder Scrolls Wiki:Blocking policy',
#  'The Elder Scrolls Wiki:Blog policy',
#  'The Elder Scrolls Wiki:Bots',
#  'The Elder Scrolls Wiki:Chat',
#  'The Elder Scrolls Wiki:Community Portal',
#  'The Elder Scrolls Wiki:Comprehensive Articles',
#  'The Elder Scrolls Wiki:Consensus',
#  'The Elder Scrolls Wiki:Discord Moderators',
#  'The Elder Scrolls Wiki:Discussions',
#  'The Elder Scrolls Wiki:Featured Articles',
#  'The Elder Scrolls Wiki:Good Articles',
#  'The Elder Scrolls Wiki:Media',
#  'The Elder Scrolls Wiki:Member of the Month',
#  'The Elder Scrolls Wiki:Moderators',
#  'The Elder Scrolls Wiki:Moot',
#  'The Elder Scrolls Wiki:Neutral point of view',
#  'The Elder Scrolls Wiki:News',
#  'The Elder Scrolls Wiki:News Team',
#  'The Elder Scrolls Wiki:PAG',
#  'The Elder Scrolls Wiki:Patrollers',
#  'The Elder Scrolls Wiki:Policies and Guidelines',
#  'The Elder Scrolls Wiki:Sandbox',
#  'The Elder Scrolls Wiki:Staff',
#  'The Elder Scrolls Wiki:Style and Formatting',
#  'The Elder Scrolls Wiki:VIP',
#  'The Elder Scrolls Wiki:Vandalism in progress',
#  'The Elder Scrolls Wiki:Weekly Updates',
#  'The Elder Scrolls Wiki?action=edit',
#  'The Elder Scrolls Wiki?action=history',
#  'The Elder Scrolls: Arena',
#  'The Elder Scrolls: Blades',
#  'The Elder Scrolls: Legends',
#  'The Queen%27s Decree',
#  'Thieves Guild (Skyrim)#Quests',
#  'Timeline',
#  'Trainers (Skyrim)',
#  'Ultimate Skills',
#  'User blog:Amulet of Kings/ESO: Gates of Oblivion storyline and Blackwood chapter revealed',
#  'User blog:Amulet of Kings/ESO: Markarth %26 Update 28 Released on PC %26 Mac',
#  'User blog:Poisoned apples/ESO: Stonethorn and Update 27 Released on PC, Mac, and Stadia',
#  'User blog:Stygies VIII/Community Interviews: LadyNerevar',
#  'Vampirism (Skyrim)',
#  'Vestige',
#  'Vvardenfell (Online)',
#  'Warden',
#  'Wayshrines (Online)',
#  'Weapons (Skyrim)']

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
